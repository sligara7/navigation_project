# %% [markdown]
# # Navigation
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %% [markdown]
# The environment is already saved in the Workspace and can be accessed at the file path provided below.  Please run the next code cell without making any changes.

# %%
# !pip install unityagents
from unityagents import UnityEnvironment
import numpy as np

# please do not modify the line below
env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64")
# Out:
# Requirement already satisfied: unityagents in /home/sligara7/miniconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: matplotlib in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (3.5.2)
# Requirement already satisfied: tensorflow>=1.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (2.9.1)
# Requirement already satisfied: pytest>=3.2.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (7.1.2)
# Requirement already satisfied: docopt in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (0.6.2)
# Requirement already satisfied: jupyter in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (1.0.0)
# Requirement already satisfied: mock>=2.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (4.0.3)
# Requirement already satisfied: Pillow>=4.2.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (9.1.1)
# Requirement already satisfied: numpy>=1.11.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from unityagents) (1.22.4)
# Requirement already satisfied: attrs>=19.2.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (21.4.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (1.0.0)
# Requirement already satisfied: iniconfig in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (1.1.1)
# Requirement already satisfied: packaging in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (21.3)
# Requirement already satisfied: py>=1.8.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pytest>=3.2.2->unityagents) (2.0.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (14.0.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.1.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.12)
# Requirement already satisfied: absl-py>=1.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (3.7.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (2.9.0)
# Requirement already satisfied: setuptools in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (62.3.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (3.19.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.46.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (4.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorflow>=1.0->unityagents) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=1.0->unityagents) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (2.1.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (2.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (2.28.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.0->unityagents) (3.2.0)
# Requirement already satisfied: notebook in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (6.4.12)
# Requirement already satisfied: jupyter-console in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (6.4.3)
# Requirement already satisfied: nbconvert in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (6.5.0)
# Requirement already satisfied: ipykernel in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (6.13.1)
# Requirement already satisfied: qtconsole in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (5.3.1)
# Requirement already satisfied: ipywidgets in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter->unityagents) (7.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (7.3.4)
# Requirement already satisfied: traitlets>=5.1.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (5.2.2.post1)
# Requirement already satisfied: tornado>=6.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (6.1)
# Requirement already satisfied: nest-asyncio in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (1.6.0)
# Requirement already satisfied: psutil in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (5.9.1)
# Requirement already satisfied: ipython>=7.23.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->unityagents) (8.4.0)
# Requirement already satisfied: backcall in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.2.0)
# Requirement already satisfied: decorator in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (5.1.1)
# Requirement already satisfied: stack-data in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (2.12.0)
# Requirement already satisfied: pickleshare in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->unityagents) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->unityagents) (4.10.0)
# Requirement already satisfied: entrypoints in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->unityagents) (0.4)
# Requirement already satisfied: pyzmq>=23.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->unityagents) (23.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sligara7/miniconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.2.5)
# Requirement already satisfied: nbformat>=4.2.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->unityagents) (5.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->unityagents) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->unityagents) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->unityagents) (1.1.0)
# Requirement already satisfied: fastjsonschema in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->unityagents) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->unityagents) (4.6.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->unityagents) (0.18.1)
# Requirement already satisfied: terminado>=0.8.3 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from notebook->jupyter->unityagents) (0.15.0)
# Requirement already satisfied: jinja2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from notebook->jupyter->unityagents) (3.1.2)
# Requirement already satisfied: argon2-cffi in /home/sligara7/miniconda3/lib/python3.9/site-packages (from notebook->jupyter->unityagents) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from notebook->jupyter->unityagents) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/sligara7/miniconda3/lib/python3.9/site-packages (from notebook->jupyter->unityagents) (0.14.1)
# Requirement already satisfied: jupyterlab-pygments in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (4.11.1)
# Requirement already satisfied: bleach in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (5.0.0)
# Requirement already satisfied: defusedxml in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (2.1.1)
# Requirement already satisfied: tinycss2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->unityagents) (1.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/sligara7/miniconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->unityagents) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->unityagents) (1.15.0)
# Requirement already satisfied: pycparser in /home/sligara7/miniconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->unityagents) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->unityagents) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/sligara7/miniconda3/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->unityagents) (0.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from matplotlib->unityagents) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from matplotlib->unityagents) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from matplotlib->unityagents) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from matplotlib->unityagents) (4.33.3)
# Requirement already satisfied: qtpy>=2.0.1 in /home/sligara7/miniconda3/lib/python3.9/site-packages (from qtconsole->jupyter->unityagents) (2.1.0)
# Requirement already satisfied: executing in /home/sligara7/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.8.3)
# Requirement already satisfied: asttokens in /home/sligara7/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->unityagents) (2.0.5)
# Requirement already satisfied: pure-eval in /home/sligara7/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->unityagents) (0.2.2)
# ---------------------------------------------------------------------------
# UnityEnvironmentException                 Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       3 import numpy as np
#       5 # please do not modify the line below
# ----> 6 env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64")
#
# File ~/miniconda3/lib/python3.9/site-packages/unityagents/environment.py:86, in UnityEnvironment.__init__(self, file_name, worker_id, base_port, curriculum)
#      84 if launch_string is None:
#      85     self.close()
# ---> 86     raise UnityEnvironmentException("Couldn't launch the {0} environment. "
#      87                                     "Provided filename does not match any environments."
#      88                                     .format(true_filename))
#      89 else:
#      90     # Launch Unity environment
#      91     proc1 = subprocess.Popen(
#      92         [launch_string,
#      93          '--port', str(self.port)])
#
# UnityEnvironmentException: Couldn't launch the Banana environment. Provided filename does not match any environments.

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [ 1.          0.          0.          0.          0.84408134  0.          0.
#   1.          0.          0.0748472   0.          1.          0.          0.
#   0.25755     1.          0.          0.          0.          0.74177343
#   0.          1.          0.          0.          0.25854847  0.          0.
#   1.          0.          0.09355672  0.          1.          0.          0.
#   0.31969345  0.          0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agent while it is training**, and you should set `train_mode=True` to restart the environment.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class QNetwork(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed=47, fc1_units=64, fc2_units=128):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        # self.fc3 = nn.Linear(fc2_units, fc3_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        # x = F.relu(self.fc3(x))
        return self.fc3(x)

# %%
import random
from collections import namedtuple, deque

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 5e-4               # learning rate 
UPDATE_EVERY = 4        # how often to update the network

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Agent():
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)
        self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0
    
    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)
        
        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.
        
        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current states 
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Get expected Q values from local model
        Q_expected = self.qnetwork_local(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # ------------------- update target network ------------------- #
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)


class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.

        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
  
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
def dqn(model_, n_episodes=20000, max_t=2000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        # print(i_episode)
        env_info = env.reset(train_mode=True)[model_]
        state = env_info.vector_observations[0] 
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps)
            env_info = env.step(action)[model_]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished 
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
        if np.mean(scores_window)>=13.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            break
    return scores

# %%
env_info = env.reset(train_mode=True)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
while True:
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))

# %%
env_info.vector_observations[0].shape[0]
brain.vector_action_space_size
# Out:
# 4

# %% [markdown]
# When finished, you can close the environment.

# %%
agent = Agent(state_size=state_size, action_size=action_size, seed=0)

scores = dqn(brain_name)
# load the weights from file
agent.qnetwork_local.load_state_dict(torch.load('checkpoint.pth'))
            
env.close()
# Out:
# Episode 100	Average Score: 0.76
# Episode 200	Average Score: 3.43
# Episode 300	Average Score: 7.85
# Episode 400	Average Score: 10.43
# Episode 500	Average Score: 11.71
# Episode 537	Average Score: 13.01
# Environment solved in 437 episodes!	Average Score: 13.01

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agent while it is training.  However, **_after training the agent_**, you can download the saved model weights to watch the agent on your own machine!
